# %%
import moxing as mx

data_export = "s3://zai2020/data_export/"
print(mx.file.list_directory(data_export))
nbt_save = "s3://zai2020/nbt_save/"
print(mx.file.list_directory(nbt_save))
# Out:
# INFO:root:Using MoXing-v1.17.1-47ce498c
# INFO:root:Using OBS-Python-SDK-3.1.2
# ['0805002', '0805003']
# ---------------------------------------------------------------------------
# MoxFileNotExistsException                 Traceback (most recent call last)
# <ipython-input-1-df21b1bc9055> in <module>()
#       4 print(mx.file.list_directory(data_export))
#       5 nbt_save = "s3://zai2020/nbt_save/"
# ----> 6 print(mx.file.list_directory(nbt_save))
#
# ~/anaconda3/envs/TensorFlow-2.1.0/lib/python3.6/site-packages/moxing/framework/util/runtime.py in wrapper(*args, **kwargs)
#     252
#     253     else:
# --> 254       return func(*args, **kwargs)
#     255
#     256   return functools.wraps(func)(wrapper)
#
# ~/anaconda3/envs/TensorFlow-2.1.0/lib/python3.6/site-packages/moxing/framework/file/file_io.py in list_directory(url, recursive, remove_sep, skip_file, skip_dir)
#     942
#     943   obs_client = _create_or_get_obs_client()
# --> 944   return _list_directory_obs(obs_client, bucket_name, object_key, recursive, remove_sep, skip_file, skip_dir)
#     945
#     946
#
# ~/anaconda3/envs/TensorFlow-2.1.0/lib/python3.6/site-packages/moxing/framework/file/file_io.py in _list_directory_obs(obs_client, bucket_name, object_key, recursive, remove_sep, skip_file, skip_dir)
#     960     if not _is_directory_obs(obs_client, bucket_name, object_key):
#     961       raise MoxFileNotExistsException('Could not find directory. bucket_name=%s, object_key=%s' % (
# --> 962         bucket_name, object_key))
#     963
#     964   return ret
#
# MoxFileNotExistsException: Could not find directory. bucket_name=zai2020, object_key=nbt_save/

# %% [markdown]
# # Saving YOLOv5 weights to s3

# %%
prefix = "yolo"
yolo_folder = "yolov5/runs/"
dst = nbt_save + prefix
mx.file.copy_parallel(yolo_folder, dst)

# %% [markdown]
# # Clean old YOLOv5 data
