# %%
from moxing import file

weight_file = "runs/exp5/weights/best.pt"
model_name = "0806yolom001"

print(weight_file)
print(model_name)
# Out:
# runs/exp5/weights/best.pt
# 0806yolom001

# %%
dst = "s3://zai2020/nbt_mod/" + model_name + "/model/"
file.copy_parallel("pub", dst)
file.copy(weight_file, dst + "best.pt")
